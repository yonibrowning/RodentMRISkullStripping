# %%
import numpy as np
from matplotlib import pyplot as plt

loss = np.load('./loss.npy')
val_loss= np.load('./val_loss.npy')
dice= np.load('./dice_coef.npy')
val_dice= np.load('./val_dice_coef.npy')

# %%
fig,ax = plt.subplots(ncols= 1)
ax.plot(dice,label = 'Training')
ax.plot(val_dice,label = 'Validation')
ax.set_xlabel('epoch')
ax.set_ylabel('DICE')
ax.legend()
ax.set_title('Dice Training History')
# Out:
# Text(0.5, 1.0, 'Dice Training History')
